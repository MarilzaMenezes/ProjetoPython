# %% [markdown]
# <a href="https://colab.research.google.com/github/MarilzaMenezes/ProjetoPython/blob/main/projetoIAteste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.read_csv('analise_op.csv', sep = ';' , encoding= 'ISO-8859-1')
# Out:
#                INTERESSADO  UF TIPO_INTERESSE                TIPO_OPERACAO  \
# 0      Abadia dos Dourados  MG      Município  Operação Contratual Interna
# 1      Abadia dos Dourados  MG      Município  Operação Contratual Interna
# 2      Abadia dos Dourados  MG      Município  Operação Contratual Interna
# 3      Abadia dos Dourados  MG      Município  Operação Contratual Interna
# 4      Abadia dos Dourados  MG      Município  Operação Contratual Interna
# ...                    ...  ..            ...                          ...
# 23637             Zacarias  SP      Município  Operação Contratual Interna
# 23638               Zortéa  SC      Município  Operação Contratual Interna
# 23639               Zortéa  SC      Município  Operação Contratual Interna
# 23640               Zortéa  SC      Município  Operação Contratual Interna
# 23641               Zortéa  SC      Município  Operação Contratual Interna
#
#                                               FINALIDADE  \
# ...
